# %%
# Importing packages for ML Training
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels as sm
from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.linear_model import SGDRegressor
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
#dataList = [0.5, 0.001, 1, 0.9, 0.007, 1.1, 0.1, 0.23, 0.29, 0.3, 0.4, 0.7 ]
#numCols = 6
#plt.hist(dataList, numCols)
#plt.show()
# Loading dataset
encodings = []
na = pd.read_csv('../Datasets/North Atlantic Dataset.csv', encoding= "latin-1")

# %%
na.head()
# Out:
#    OBJECTID          Oceans Regions  SubRegions Country State Beach Location  \
# 0      3171  Atlantic Ocean     NaN         NaN     NaN   NaN            NaN
# 1      3170  Atlantic Ocean     NaN         NaN     NaN   NaN            NaN
# 2      1786  Atlantic Ocean     NaN         NaN     NaN   NaN            NaN
# 3      3932  Atlantic Ocean     NaN         NaN     NaN   NaN            NaN
# 4      2316  Atlantic Ocean     NaN         NaN     NaN   NaN            NaN
#
#   Marine Setting  Ocean Bottom Depth (m)  Sediment Sample Depth (m)  ...  \
# 0    Ocean water                     NaN                        NaN  ...
# 1    Ocean water                     NaN                        NaN  ...
# 2    Ocean water                     NaN                        NaN  ...
# 3    Ocean water                     NaN                        NaN  ...
# 4    Ocean water                     NaN                        NaN  ...
#
# ...

# %%
na.isnull().sum
# Out:
# <bound method DataFrame.sum of       OBJECTID  Oceans  Regions  SubRegions  Country  State  Beach Location  \
# 0        False   False     True        True     True   True            True
# 1        False   False     True        True     True   True            True
# 2        False   False     True        True     True   True            True
# 3        False   False     True        True     True   True            True
# 4        False   False     True        True     True   True            True
# ...        ...     ...      ...         ...      ...    ...             ...
# 3330     False   False    False        True     True   True            True
# 3331     False   False    False        True     True   True            True
# 3332     False   False    False        True     True   True            True
# 3333     False   False    False        True     True   True            True
# 3334     False   False    False        True     True   True            True
#
# ...

# %%
#Preprocessing
X = na.iloc[:,1:2].values  #features
y = na.iloc[:,2].values  # Target variable
